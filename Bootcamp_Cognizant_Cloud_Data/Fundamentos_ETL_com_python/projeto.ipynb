# %%
# !pip install pandera
# Out:
# Collecting pandera
#   Downloading pandera-0.9.0-py3-none-any.whl (197 kB)
#      -------------------------------------- 197.8/197.8 KB 4.0 MB/s eta 0:00:00
# Collecting pydantic
#   Downloading pydantic-1.9.0-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 9.6 MB/s eta 0:00:00
# Collecting pyarrow
#   Downloading pyarrow-7.0.0-cp39-cp39-win_amd64.whl (16.1 MB)
#      ---------------------------------------- 16.1/16.1 MB 8.4 MB/s eta 0:00:00
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting wrapt
#   Downloading wrapt-1.14.0-cp39-cp39-win_amd64.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.22.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from pandera) (21.3)
# Requirement already satisfied: pandas>=1.0 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->pandera) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.0->pandera) (2021.3)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typing-extensions>=3.7.4
#   Using cached typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.5 in c:\users\clientecms\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0->pandera) (1.16.0)
# Installing collected packages: mypy-extensions, wrapt, typing-extensions, pyarrow, typing-inspect, pydantic, pandera
# Successfully installed mypy-extensions-0.4.3 pandera-0.9.0 pyarrow-7.0.0 pydantic-1.9.0 typing-extensions-4.1.1 typing-inspect-0.7.1 wrapt-1.14.0

# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                 ****     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                 ****     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                 ****     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia': pa.Column(pa.Int),
        'codigo_ocorrencia2': pa.Column(pa.Int),
        'ocorrencia_classificacao': pa.Column(pa.String),
        'ocorrencia_cidade': pa.Column(pa.String),
        'ocorrencia_uf': pa.Column(pa.String, pa.Check.str_length(2,2)),
        'ocorrencia_aerodromo': pa.Column(pa.String),
        'ocorrencia_dia': pa.Column(pa.DateTime),
        'ocorrencia_hora': pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        'total_recomendacoes': pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5752 rows x 9 columns]

# %% [raw]
# df.dtypes
# df.ocorrencia_dia.dt.month
